# %%
# ── imports ──────────────────────────────────────────────────────
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

# generation
from lhcb_velo_toy.generation import (
    PlaneGeometry,
    StateEventGenerator,
)

# solvers
from lhcb_velo_toy.solvers import (
    SimpleHamiltonianFast,
    get_tracks,
)

# analysis
from lhcb_velo_toy.analysis import EventValidator, Match
from lhcb_velo_toy.analysis.plotting.event_display import (
    plot_event_3d,
    plot_reco_vs_truth,
)

# %matplotlib inline
plt.rcParams["figure.dpi"] = 120

# ── helper: build geometry from high-level parameters ───────────
def make_geometry(n_modules: int, z_first: float = 100.0, z_spacing: float = 33.0,
                  half_x: float = 50.0, half_y: float = 50.0) -> PlaneGeometry:
    """Create a PlaneGeometry with evenly spaced modules."""
    z_positions = [z_first + i * z_spacing for i in range(n_modules)]
    return PlaneGeometry(
        module_id=list(range(n_modules)),
        lx=[half_x] * n_modules,
        ly=[half_y] * n_modules,
        z=z_positions,
    )

# ── helper: generate a complete event ───────────────────────────
def generate_event(geo, n_tracks, measurement_error=0.0, collision_noise=1e-8,
                   phi_max=0.2, theta_max=0.2):
    """Generate a full event end-to-end."""
    gen = StateEventGenerator(
        detector_geometry=geo,
        events=1,
        n_particles=[n_tracks],
        phi_min=-phi_max, phi_max=phi_max,
        theta_min=-theta_max, theta_max=theta_max,
        measurement_error=measurement_error,
        collision_noise=collision_noise,
    )
    gen.generate_random_primary_vertices({"x": 0.1, "y": 0.1, "z": 50.0})
    particles = [[{"type": "pion", "mass": 139.6, "q": 1}] * n_tracks]
    gen.generate_particles(particles)
    event = gen.generate_complete_events()
    return gen, event

# ── helper: compute epsilon from physics parameters ─────────────
def compute_epsilon(sigma_res, sigma_scatt, dz, scale=1.0, theta_min=1.5e-5):
    """Compute angular acceptance threshold epsilon.

    Uses the paper formula with weighting factors:
        ε = scale × √(2·θ_s² + 12·θ_r² + 2·θ_min²)

    Parameters
    ----------
    sigma_res : float
        Measurement resolution (same units as dz, e.g. mm).
    sigma_scatt : float
        Multiple scattering angle (radians).
    dz : float
        Module spacing (same units as sigma_res).
    scale : float
        Number of sigma to accept (default 1.0).
    theta_min : float
        Minimum threshold to avoid numerical instability (rad).

    Returns
    -------
    float
        Epsilon threshold in radians.
    """
    theta_s = scale * sigma_scatt
    theta_r = np.arctan((scale * sigma_res) / dz) if dz != 0 else 0.0
    return float(np.sqrt(2 * theta_s**2 + 12 * theta_r**2 + 2 * theta_min**2))

print("All imports successful.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # ── imports ──────────────────────────────────────────────────────
# ----> 2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 from IPython.display import display, Markdown
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# ── generate a clean event ──────────────────────────────────────
# 5 modules, 33mm spacing (z: 100-232mm), 50mm half-width
# With max slopes ~0.2 rad, tracks travel ~26mm laterally over 132mm in z
# → all tracks stay well within acceptance
N_TRACKS_CLEAN = 3
N_MODULES_CLEAN = 5

geo_clean = make_geometry(N_MODULES_CLEAN, z_spacing=33.0)

# Retry until we get an event where every track has >= 3 hits
# (rare acceptance losses can occur at boundaries)
for attempt in range(20):
    gen_clean, event_clean = generate_event(geo_clean, N_TRACKS_CLEAN)
    min_hits = min(len(t.hit_ids) for t in event_clean.tracks)
    if min_hits >= 3:
        break

print(f"Clean event: {len(event_clean.tracks)} tracks, "
      f"{len(event_clean.hits)} hits across {len(event_clean.modules)} modules")
for trk in event_clean.tracks:
    print(f"  Track {trk.track_id}: {len(trk.hit_ids)} hits")
# Out:
# Clean event: 3 tracks, 15 hits across 5 modules
#   Track 0: 5 hits
#   Track 1: 5 hits
#   Track 2: 5 hits

# %%
# ── 3-D truth display ───────────────────────────────────────────
fig_truth = plot_event_3d(event_clean, title="Clean Event — Truth Tracks")
plt.savefig('baseline_fig1_truth_3d.png', bbox_inches='tight', dpi=120)
plt.show()

# %%
# ── build Hamiltonian & solve classically ────────────────────────
# Physics parameters for epsilon computation
SIGMA_RES   = 0.0     # measurement resolution (mm) — 0 for clean event
SIGMA_SCATT = 1e-3    # collision noise (rad) — matches generate_event default
DZ_MM       = 33.0    # module spacing (mm)
SCALE       = 3.0     # accept segment pairs within 3σ

EPSILON = compute_epsilon(SIGMA_RES, SIGMA_SCATT, DZ_MM, scale=SCALE)
GAMMA   = 1.5    # self-interaction penalty
DELTA   = 1.0    # bias weight

print(f"Computed ε = {EPSILON:.6f} rad ({EPSILON*1e3:.3f} mrad)")

ham_clean = SimpleHamiltonianFast(epsilon=EPSILON, gamma=GAMMA, delta=DELTA)
A_clean, b_clean = ham_clean.construct_hamiltonian(event_clean)
x_clean = ham_clean.solve_classicaly()

# An uncoupled (fake) segment has activation δ/(δ+γ).
# True segments, boosted by collinear couplings, sit above this.
BASELINE = DELTA / (DELTA + GAMMA)
THRESHOLD = (1 + BASELINE) / 2          # midpoint → clear separator

print(f"Segments:  {ham_clean.n_segments}")
print(f"Matrix A:  {A_clean.shape[0]}×{A_clean.shape[1]}, nnz={A_clean.nnz}")
print(f"Uncoupled baseline:  x ≈ {BASELINE:.3f}")
print(f"Threshold:           {THRESHOLD:.3f}")
print(f"Active (above thr):  {np.sum(x_clean > THRESHOLD)} / {len(x_clean)} segments")
print(f"Min / Max activation: {x_clean.min():.4f} / {x_clean.max():.4f}")
# Out:
# Computed ε = 0.004243 rad (4.243 mrad)
# Segments:  36
# Matrix A:  36×36, nnz=54
# Uncoupled baseline:  x ≈ 0.400
# Threshold:           0.700
# Active (above thr):  12 / 36 segments
# Min / Max activation: 0.4000 / 1.2727

# %%
# ── reconstruct tracks ──────────────────────────────────────────
reco_clean = get_tracks(ham_clean, x_clean, event_clean, threshold=THRESHOLD)
print(f"Reconstructed {len(reco_clean)} tracks")
for trk in reco_clean:
    print(f"  Reco track {trk.track_id}: {len(trk.hit_ids)} hits")
# Out:
# Reconstructed 3 tracks
#   Reco track 0: 5 hits
#   Reco track 1: 5 hits
#   Reco track 2: 5 hits

# %%
event_clean
# Out:
# Event(detector_geometry=PlaneGeometry(module_id=[0, 1, 2, 3, 4], lx=[50.0, 50.0, 50.0, 50.0, 50.0], ly=[50.0, 50.0, 50.0, 50.0, 50.0], z=[100.0, 133.0, 166.0, 199.0, 232.0]), primary_vertices=[PrimaryVertex(pv_id=0, x=0.019900923060882734, y=-0.05815551880424294, z=30.41039083643326, track_ids=[0, 1, 2], extra={})], tracks=[Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}), Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}), Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={})], hits=[Hit(hit_id=0, x=np.float64(-6.729315205545025), y=np.float64(10.027170208660701), z=100.0, module_id=0, track_id=0, extra={}), Hit(hit_id=1, x=np.float64(-9.929852516109996), y=np.float64(14.809719521772468), z=133.0, module_id=1, track_id=0, extra={}), Hit(hit_id=2, x=np.float64(-13.13039025493901), y=np.float64(19.592268699653005), z=166.0, module_id=2, track_id=0, extra={}), Hit(hit_id=3, x=np.float64(-16.330928179487874), y=np.float64(24.374818057477704), z=199.0, module_id=3, track_id=0, extra={}), Hit(hit_id=4, x=np.float64(-19.531466700458374), y=np.float64(29.15736723150307), z=232.0, module_id=4, track_id=0, extra={}), Hit(hit_id=5, x=np.float64(-7.549673549753236), y=np.float64(4.729253809237041), z=100.0, module_id=0, track_id=1, extra={}), Hit(hit_id=6, x=np.float64(-11.13923175189817), y=np.float64(6.999485459514346), z=133.0, module_id=1, track_id=1, extra={}), Hit(hit_id=7, x=np.float64(-14.728790468667277), y=np.float64(9.269716952000524), z=166.0, module_id=2, track_id=1, extra={}), Hit(hit_id=8, x=np.float64(-18.318349098302342), y=np.float64(11.539947803769989), z=199.0, module_id=3, track_id=1, extra={}), Hit(hit_id=9, x=np.float64(-21.907907810532045), y=np.float64(13.810178176051323), z=232.0, module_id=4, track_id=1, extra={}), Hit(hit_id=10, x=np.float64(8.05136441773664), y=np.float64(13.89814438788555), z=100.0, module_id=0, track_id=2, extra={}), Hit(hit_id=11, x=np.float64(11.859954069381018), y=np.float64(20.51634383071068), z=133.0, module_id=1, track_id=2, extra={}), Hit(hit_id=12, x=np.float64(15.668543873909623), y=np.float64(27.13454381233088), z=166.0, module_id=2, track_id=2, extra={}), Hit(hit_id=13, x=np.float64(19.477133717351737), y=np.float64(33.75274317300961), z=199.0, module_id=3, track_id=2, extra={}), Hit(hit_id=14, x=np.float64(23.28572391978005), y=np.float64(40.370942956909374), z=232.0, module_id=4, track_id=2, extra={})], modules=[Module(module_id=0, z=100.0, lx=50.0, ly=50.0, hit_ids=[0, 5, 10], extra={}), Module(module_id=1, z=133.0, lx=50.0, ly=50.0, hit_ids=[1, 6, 11], extra={}), Module(module_id=2, z=166.0, lx=50.0, ly=50.0, hit_ids=[2, 7, 12], extra={}), Module(module_id=3, z=199.0, lx=50.0, ly=50.0, hit_ids=[3, 8, 13], extra={}), Module(module_id=4, z=232.0, lx=50.0, ly=50.0, hit_ids=[4, 9, 14], extra={})], metadata={'generator': 'StateEventGenerator', 'geometry_class': 'PlaneGeometry', 'n_modules': 5, 'z_positions': [100.0, 133.0, 166.0, 199.0, 232.0], 'module_ids': [0, 1, 2, 3, 4], 'phi_min': -0.2, 'phi_max': 0.2, 'theta_min': -0.2, 'theta_max': 0.2, 'events': 1, 'n_particles': [3], 'measurement_error': 0.0, 'collision_noise': 1e-08})

# %%
type(reco_clean[0])
# Out:
# lhcb_velo_toy.generation.entities.track.Track

# %%
reco_hits = [hit_id for trk in reco_clean for hit_id in trk.hit_ids]

# %%
from lhcb_velo_toy.solvers.reconstruction import construct_event

# %%
# Extract Hit objects corresponding to the reconstructed hit IDs
reco_hit_objects = [hit for hit in event_clean.hits if hit.hit_id in reco_hits]

event_reco = construct_event(
    detector_geometry=geo_clean,
    tracks=reco_clean,
    hits=reco_hit_objects
)

# %%
# ── 3-D truth display ───────────────────────────────────────────
fig_truth = plot_event_3d(event_clean, title="Clean Event — Truth Tracks")
plt.show()

# %%
# ── validate: match reco → truth ────────────────────────────────
val_clean = EventValidator(event_clean, reco_clean)
matches_clean, metrics_clean = val_clean.match_tracks(purity_min=0.7)

print("=== Clean Event Metrics ===")
for k, v in metrics_clean.items():
    print(f"  {k:25s}: {v}")

# per-track detail
print("\nPer-track matches:")
print(f"  {'Truth':>6}  {'RecHits':>7}  {'Purity':>7}  {'HitEff':>7}  {'Type'}")
for m in matches_clean:
    label = "PRIMARY" if m.is_primary else ("GHOST" if m.is_ghost else "CLONE")
    truth_str = str(m.truth_id) if m.truth_id is not None else "-"
    print(f"  {truth_str:>6}  {m.rec_hits:7d}  "
          f"{m.purity:7.3f}  {m.hit_efficiency:7.3f}  {label}")
# Out:
# === Clean Event Metrics ===
#   efficiency               : 1.0
#   ghost_rate               : 0.0
#   clone_fraction           : 0.0
#   mean_purity              : 1.0
#   hit_efficiency           : 1.0
#   n_candidates             : 3
#   n_accepted               : 3
#   n_ghosts                 : 0
#   n_clones                 : 0
#   n_primary                : 3
#   n_reconstructible        : 3
#   n_matched                : 3
#
# Per-track matches:
#    Truth  RecHits   Purity   HitEff  Type
#        0        5    1.000    1.000  PRIMARY
#        1        5    1.000    1.000  PRIMARY
#        2        5    1.000    1.000  PRIMARY

# %%
import random

# ── generate 10 events with varying track counts ────────────────

# Track counts from 2 to 6 for variety
track_counts = [2, 3, 4, 5, 6, 3, 4, 5, 2, 4]
events_data = []

for i, n_tracks in enumerate(track_counts):
    print(f"\n=== Generating Event {i} with {n_tracks} tracks ===")
    
    # Generate event with retry logic for acceptance
    for attempt in range(20):
        gen, event = generate_event(geo_clean, n_tracks)
        min_hits = min(len(t.hit_ids) for t in event.tracks)
        if min_hits >= 3:
            break
    
    print(f"  Event {i}: {len(event.tracks)} tracks, {len(event.hits)} hits")
    
    # Build Hamiltonian and solve
    ham = SimpleHamiltonianFast(epsilon=EPSILON, gamma=GAMMA, delta=DELTA)
    A, b = ham.construct_hamiltonian(event)
    x = ham.solve_classicaly()
    
    # Reconstruct tracks
    reco_tracks = get_tracks(ham, x, event, threshold=THRESHOLD)
    print(f"  Reconstructed {len(reco_tracks)} tracks")
    
    # Extract segments (true and reconstructed)
    true_segments = []
    for track in event.tracks:
        hit_ids = track.hit_ids
        for j in range(len(hit_ids) - 1):
            true_segments.append((hit_ids[j], hit_ids[j+1]))
    
    reco_segments = []
    for track in reco_tracks:
        hit_ids = track.hit_ids
        for j in range(len(hit_ids) - 1):
            reco_segments.append((hit_ids[j], hit_ids[j+1]))
    
    # Validate
    val = EventValidator(event, reco_tracks)
    matches, metrics = val.match_tracks(purity_min=0.7)
    
    # Store data
    events_data.append({
        'event_id': i,
        'n_tracks_true': len(event.tracks),
        'n_tracks_reco': len(reco_tracks),
        'event': event,
        'reco_tracks': reco_tracks,
        'true_segments': true_segments,
        'reco_segments': reco_segments,
        'matches': matches,
        'metrics': metrics,
        'ham': ham,
        'x': x
    })
    
    # Plot truth vs reco
    fig = plot_reco_vs_truth(event, reco_tracks)
    if i == 0:
        plt.savefig('baseline_fig2_reco_truth_event0.png', bbox_inches='tight', dpi=120)
    plt.show()

print("\n=== Summary ===")
print(f"{'Event':>6}  {'True':>5}  {'Reco':>5}  {'Eff':>6}  {'Ghost':>6}  {'TrueSeg':>8}  {'RecoSeg':>8}")
for ed in events_data:
    print(f"{ed['event_id']:6d}  {ed['n_tracks_true']:5d}  {ed['n_tracks_reco']:5d}  "
          f"{ed['metrics']['efficiency']:6.3f}  {ed['metrics']['ghost_rate']:6.3f}  "
          f"{len(ed['true_segments']):8d}  {len(ed['reco_segments']):8d}")
# Out:
# === Generating Event 0 with 2 tracks ===
#   Event 0: 2 tracks, 10 hits
#   Reconstructed 2 tracks
# === Generating Event 1 with 3 tracks ===
#   Event 1: 3 tracks, 15 hits
#   Reconstructed 3 tracks
# === Generating Event 2 with 4 tracks ===
#   Event 2: 4 tracks, 20 hits
#   Reconstructed 4 tracks
# === Generating Event 3 with 5 tracks ===
#   Event 3: 5 tracks, 25 hits
#   Reconstructed 5 tracks
# === Generating Event 4 with 6 tracks ===
#   Event 4: 6 tracks, 22 hits
#   Reconstructed 2 tracks
# === Generating Event 5 with 3 tracks ===
#   Event 5: 3 tracks, 15 hits
#   Reconstructed 3 tracks
# === Generating Event 6 with 4 tracks ===
#   Event 6: 4 tracks, 20 hits
#   Reconstructed 3 tracks
# === Generating Event 7 with 5 tracks ===
#   Event 7: 5 tracks, 25 hits
#   Reconstructed 5 tracks
# === Generating Event 8 with 2 tracks ===
#   Event 8: 2 tracks, 10 hits
#   Reconstructed 2 tracks
# === Generating Event 9 with 4 tracks ===
#   Event 9: 4 tracks, 20 hits
#   Reconstructed 4 tracks
# === Summary ===
#  Event   True   Reco     Eff   Ghost   TrueSeg   RecoSeg
#      0      2      2   1.000   0.000         8         8
#      1      3      3   1.000   0.000        12        12
#      2      4      4   1.000   0.000        16        16
#      3      5      5   1.000   0.000        20        20
#      4      6      2   0.333   0.000        16         8
#      5      3      3   1.000   0.000        12        12
#      6      4      3   0.500   0.333        16        17
#      7      5      5   1.000   0.000        20        20
#      8      2      2   1.000   0.000         8         8
#      9      4      4   1.000   0.000        16        16

# %%
# ── Pairwise segment angles (shared middle hit) — Clean Event ────
# The Hamiltonian checks the angle BETWEEN consecutive segments
# sharing a middle hit, not the angle w.r.t. the beam.

hits_dict_clean = {hit.hit_id: hit for hit in event_clean.hits}

def pairwise_angle(h_a, h_b, h_c, hd):
    """Angle between segment (a->b) and (b->c) sharing middle hit b."""
    ha, hb, hc = hd[h_a], hd[h_b], hd[h_c]
    v1 = np.array([hb.x - ha.x, hb.y - ha.y, hb.z - ha.z])
    v2 = np.array([hc.x - hb.x, hc.y - hb.y, hc.z - hb.z])
    cos_a = np.clip(
        np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)),
        -1.0, 1.0)
    return np.arccos(cos_a)

def pairwise_angles_from_tracks(tracks, hd):
    """Angles between consecutive segment pairs on each track."""
    angles = []
    for trk in tracks:
        hids = trk.hit_ids
        for k in range(len(hids) - 2):
            angles.append(pairwise_angle(hids[k], hids[k+1], hids[k+2], hd))
    return np.array(angles) if angles else np.array([])

true_seg_angles_clean = pairwise_angles_from_tracks(event_clean.tracks, hits_dict_clean)
reco_seg_angles_clean = pairwise_angles_from_tracks(reco_clean, hits_dict_clean)

# Plot
hi = max(0.01, max(true_seg_angles_clean.max(), reco_seg_angles_clean.max()) * 1.5) if len(true_seg_angles_clean) else 0.01
bins = np.linspace(0, hi, 60)

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

axes[0].hist(true_seg_angles_clean, bins=bins, color='forestgreen', alpha=0.8,
             edgecolor='black', lw=0.5, label=f'True ({len(true_seg_angles_clean)})')
axes[0].axvline(EPSILON, color='blue', ls='--', lw=2, label=f'e = {EPSILON:.4f}')
axes[0].set_title('True Consecutive-Segment Pair Angles', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Angle between segments sharing middle hit (rad)', fontsize=12)
axes[0].set_ylabel('Count', fontsize=12)
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

axes[1].hist(reco_seg_angles_clean, bins=bins, color='royalblue', alpha=0.8,
             edgecolor='black', lw=0.5, label=f'Reco ({len(reco_seg_angles_clean)})')
axes[1].axvline(EPSILON, color='red', ls='--', lw=2, label=f'e = {EPSILON:.4f}')
axes[1].set_title('Reco Consecutive-Segment Pair Angles', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Angle between segments sharing middle hit (rad)', fontsize=12)
axes[1].set_ylabel('Count', fontsize=12)
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

plt.suptitle('Pairwise Segment Angles - Clean Event', fontsize=15, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('baseline_fig3_seg_angles_clean.png', bbox_inches='tight', dpi=120)
plt.show()

print(f"True pairs: {len(true_seg_angles_clean)}, mean = {true_seg_angles_clean.mean():.6f} rad ({true_seg_angles_clean.mean()*1e3:.3f} mrad)")
print(f"Reco pairs: {len(reco_seg_angles_clean)}, mean = {reco_seg_angles_clean.mean():.6f} rad ({reco_seg_angles_clean.mean()*1e3:.3f} mrad)")
print(f"epsilon = {EPSILON:.6f} rad ({EPSILON*1e3:.3f} mrad)")
# Out:
# True pairs: 9, mean = 0.000000 rad (0.000 mrad)
# Reco pairs: 9, mean = 0.000000 rad (0.000 mrad)
# epsilon = 0.004243 rad (4.243 mrad)

# %%
events_data
# Out:
# [{'event_id': 0,
#   'n_tracks_true': 2,
#   'n_tracks_reco': 2,
#   'event': Event(detector_geometry=PlaneGeometry(module_id=[0, 1, 2, 3, 4], lx=[50.0, 50.0, 50.0, 50.0, 50.0], ly=[50.0, 50.0, 50.0, 50.0, 50.0], z=[100.0, 133.0, 166.0, 199.0, 232.0]), primary_vertices=[PrimaryVertex(pv_id=0, x=-0.06015169034540513, y=0.13958556305524525, z=-1.292739811330924, track_ids=[0, 1], extra={})], tracks=[Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}), Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={})], hits=[Hit(hit_id=0, x=np.float64(-17.0702347222282), y=np.float64(4.076514152031826), z=100.0, module_id=0, track_id=0, extra={}), Hit(hit_id=1, x=np.float64(-22.61192268459903), y=np.float64(5.35911954045055), z=133.0, module_id=1, track_id=0, extra={}), Hit(hit_id=2, x=np.float64(-28.153610570165164), y=np.float64(6.641725052236647), z=166.0, module_id=2, track_id=0, extra={}), Hit(hit_id=3, x=np.float64(-33.695298437291264), y=np.float64(7.924330659007378), z=199.0, module_id=3, track_id=0, extra={}), Hit(hit_id=4, x=np.float64(-39.236986292745456), y=np.float64(9.206936624797933), z=232.0, module_id=4, track_id=0, extra={}), Hit(hit_id=5, x=np.float64(7.572876684510525), y=np.float64(0.7045546169907172), z=100.0, module_id=0, track_id=1, extra={}), Hit(hit_id=6, x=np.float64(10.059628514557467), y=np.float64(0.8886148591263594), z=133.0, module_id=1, track_id=1, extra={}), Hit(hit_id=7, x=np.float64(12.546380341171732), y=np.float64(1.0726755726356065), z=166.0, module_id=2, track_id=1, extra={}), Hit(hit_id=8, x=np.float64(15.03313179004305), y=np.float64(1.256736196580434), z=199.0, module_id=3, track_id=1, extra={}), Hit(hit_id=9, x=np.float64(17.519883321864814), y=np.float64(1.4407961811371177), z=232.0, module_id=4, track_id=1, extra={})], modules=[Module(module_id=0, z=100.0, lx=50.0, ly=50.0, hit_ids=[0, 5], extra={}), Module(module_id=1, z=133.0, lx=50.0, ly=50.0, hit_ids=[1, 6], extra={}), Module(module_id=2, z=166.0, lx=50.0, ly=50.0, hit_ids=[2, 7], extra={}), Module(module_id=3, z=199.0, lx=50.0, ly=50.0, hit_ids=[3, 8], extra={}), Module(module_id=4, z=232.0, lx=50.0, ly=50.0, hit_ids=[4, 9], extra={})], metadata={'generator': 'StateEventGenerator', 'geometry_class': 'PlaneGeometry', 'n_modules': 5, 'z_positions': [100.0, 133.0, 166.0, 199.0, 232.0], 'module_ids': [0, 1, 2, 3, 4], 'phi_min': -0.2, 'phi_max': 0.2, 'theta_min': -0.2, 'theta_max': 0.2, 'events': 1, 'n_particles': [2], 'measurement_error': 0.0, 'collision_noise': 1e-08}),
#   'reco_tracks': [Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}),
#    Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={})],
#   'true_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9)],
#   'reco_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9)],
#   'matches': [Match(best_truth_id=0, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=0, is_clone=False),
#    Match(best_truth_id=1, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=1, is_clone=False)],
#   'metrics': {'efficiency': 1.0,
#    'ghost_rate': 0.0,
#    'clone_fraction': 0.0,
#    'mean_purity': 1.0,
#    'hit_efficiency': 1.0,
#    'n_candidates': 2,
#    'n_accepted': 2,
#    'n_ghosts': 0,
#    'n_clones': 0,
#    'n_primary': 2,
#    'n_reconstructible': 2,
#    'n_matched': 2},
#   'ham': <lhcb_velo_toy.solvers.hamiltonians.fast.SimpleHamiltonianFast at 0x7fccd590d400>,
#   'x': array([0.90909091, 0.4       , 0.4       , 0.90909091, 1.27272727,
#          0.4       , 0.4       , 1.27272727, 1.27272727, 0.4       ,
#          0.4       , 1.27272727, 0.90909091, 0.4       , 0.4       ,
#          0.90909091])},
#  {'event_id': 1,
#   'n_tracks_true': 3,
#   'n_tracks_reco': 3,
#   'event': Event(detector_geometry=PlaneGeometry(module_id=[0, 1, 2, 3, 4], lx=[50.0, 50.0, 50.0, 50.0, 50.0], ly=[50.0, 50.0, 50.0, 50.0, 50.0], z=[100.0, 133.0, 166.0, 199.0, 232.0]), primary_vertices=[PrimaryVertex(pv_id=0, x=0.025871561574291647, y=0.013366447010407343, z=73.96001929882358, track_ids=[0, 1, 2], extra={})], tracks=[Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}), Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}), Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={})], hits=[Hit(hit_id=0, x=np.float64(2.356253447794325), y=np.float64(3.4140219615553327), z=100.0, module_id=0, track_id=0, extra={}), Hit(hit_id=1, x=np.float64(5.309504591908), y=np.float64(7.723611665179265), z=133.0, module_id=1, track_id=0, extra={}), Hit(hit_id=2, x=np.float64(8.262755532889452), y=np.float64(12.033200904242364), z=166.0, module_id=2, track_id=0, extra={}), Hit(hit_id=3, x=np.float64(11.216006353249059), y=np.float64(16.34278953031248), z=199.0, module_id=3, track_id=0, extra={}), Hit(hit_id=4, x=np.float64(14.16925680623), y=np.float64(20.65237823132381), z=232.0, module_id=4, track_id=0, extra={}), Hit(hit_id=5, x=np.float64(-2.782747696657027), y=np.float64(-3.5881832688077013), z=100.0, module_id=0, track_id=1, extra={}), Hit(hit_id=6, x=np.float64(-6.342060185323864), y=np.float64(-8.152362941834014), z=133.0, module_id=1, track_id=1, extra={}), Hit(hit_id=7, x=np.float64(-9.901373404830458), y=np.float64(-12.716542380234383), z=166.0, module_id=2, track_id=1, extra={}), Hit(hit_id=8, x=np.float64(-13.46068699220759), y=np.float64(-17.280721397173956), z=199.0, module_id=3, track_id=1, extra={}), Hit(hit_id=9, x=np.float64(-17.0200010930786), y=np.float64(-21.84490088278664), z=232.0, module_id=4, track_id=1, extra={}), Hit(hit_id=10, x=np.float64(-3.785452368310298), y=np.float64(-2.255375257073941), z=100.0, module_id=0, track_id=2, extra={}), Hit(hit_id=11, x=np.float64(-8.615474953124748), y=np.float64(-5.130510413393388), z=133.0, module_id=1, track_id=2, extra={}), Hit(hit_id=12, x=np.float64(-13.445497463296363), y=np.float64(-8.005645396375279), z=166.0, module_id=2, track_id=2, extra={}), Hit(hit_id=13, x=np.float64(-18.275519753128386), y=np.float64(-10.880780059458562), z=199.0, module_id=3, track_id=2, extra={}), Hit(hit_id=14, x=np.float64(-23.105542220224365), y=np.float64(-13.755914853699615), z=232.0, module_id=4, track_id=2, extra={})], modules=[Module(module_id=0, z=100.0, lx=50.0, ly=50.0, hit_ids=[0, 5, 10], extra={}), Module(module_id=1, z=133.0, lx=50.0, ly=50.0, hit_ids=[1, 6, 11], extra={}), Module(module_id=2, z=166.0, lx=50.0, ly=50.0, hit_ids=[2, 7, 12], extra={}), Module(module_id=3, z=199.0, lx=50.0, ly=50.0, hit_ids=[3, 8, 13], extra={}), Module(module_id=4, z=232.0, lx=50.0, ly=50.0, hit_ids=[4, 9, 14], extra={})], metadata={'generator': 'StateEventGenerator', 'geometry_class': 'PlaneGeometry', 'n_modules': 5, 'z_positions': [100.0, 133.0, 166.0, 199.0, 232.0], 'module_ids': [0, 1, 2, 3, 4], 'phi_min': -0.2, 'phi_max': 0.2, 'theta_min': -0.2, 'theta_max': 0.2, 'events': 1, 'n_particles': [3], 'measurement_error': 0.0, 'collision_noise': 1e-08}),
#   'reco_tracks': [Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}),
#    Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}),
#    Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={})],
#   'true_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14)],
#   'reco_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14)],
#   'matches': [Match(best_truth_id=0, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=0, is_clone=False),
#    Match(best_truth_id=1, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=1, is_clone=False),
#    Match(best_truth_id=2, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=2, is_clone=False)],
#   'metrics': {'efficiency': 1.0,
#    'ghost_rate': 0.0,
#    'clone_fraction': 0.0,
#    'mean_purity': 1.0,
#    'hit_efficiency': 1.0,
#    'n_candidates': 3,
#    'n_accepted': 3,
#    'n_ghosts': 0,
#    'n_clones': 0,
#    'n_primary': 3,
#    'n_reconstructible': 3,
#    'n_matched': 3},
#   'ham': <lhcb_velo_toy.solvers.hamiltonians.fast.SimpleHamiltonianFast at 0x7fccd70a1c40>,
#   'x': array([0.90909091, 0.4       , 0.4       , 0.4       , 0.90909091,
#          0.4       , 0.4       , 0.4       , 0.90909091, 1.27272727,
#          0.4       , 0.4       , 0.4       , 1.27272727, 0.4       ,
#          0.4       , 0.4       , 1.27272727, 1.27272727, 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.4       , 0.4       ,
#          0.4       , 1.27272727, 0.90909091, 0.4       , 0.4       ,
#          0.4       , 0.90909091, 0.4       , 0.4       , 0.4       ,
#          0.90909091])},
#  {'event_id': 2,
#   'n_tracks_true': 4,
#   'n_tracks_reco': 4,
#   'event': Event(detector_geometry=PlaneGeometry(module_id=[0, 1, 2, 3, 4], lx=[50.0, 50.0, 50.0, 50.0, 50.0], ly=[50.0, 50.0, 50.0, 50.0, 50.0], z=[100.0, 133.0, 166.0, 199.0, 232.0]), primary_vertices=[PrimaryVertex(pv_id=0, x=0.11511674667745558, y=0.10845186806439625, z=-18.150261495053044, track_ids=[0, 1, 2, 3], extra={})], tracks=[Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}), Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}), Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={}), Track(track_id=3, pv_id=0, hit_ids=[15, 16, 17, 18, 19], extra={})], hits=[Hit(hit_id=0, x=np.float64(-21.84478641126399), y=np.float64(-12.21902687107806), z=100.0, module_id=0, track_id=0, extra={}), Hit(hit_id=1, x=np.float64(-27.97830458955933), y=np.float64(-15.662157646576397), z=133.0, module_id=1, track_id=0, extra={}), Hit(hit_id=2, x=np.float64(-34.11182253141297), y=np.float64(-19.10528879487174), z=166.0, module_id=2, track_id=0, extra={}), Hit(hit_id=3, x=np.float64(-40.24534024155171), y=np.float64(-22.54841948424134), z=199.0, module_id=3, track_id=0, extra={}), Hit(hit_id=4, x=np.float64(-46.378857551079086), y=np.float64(-25.991550824907154), z=232.0, module_id=4, track_id=0, extra={}), Hit(hit_id=5, x=np.float64(-16.854319672292664), y=np.float64(-20.065478717917802), z=100.0, module_id=0, track_id=1, extra={}), Hit(hit_id=6, x=np.float64(-21.593974305571628), y=np.float64(-25.70016529336666), z=133.0, module_id=1, track_id=1, extra={}), Hit(hit_id=7, x=np.float64(-26.333629151407752), y=np.float64(-31.334851264568442), z=166.0, module_id=2, track_id=1, extra={}), Hit(hit_id=8, x=np.float64(-31.073283838006397), y=np.float64(-36.969537393022065), z=199.0, module_id=3, track_id=1, extra={}), Hit(hit_id=9, x=np.float64(-35.812938470280415), y=np.float64(-42.60422317196337), z=232.0, module_id=4, track_id=1, extra={}), Hit(hit_id=10, x=np.float64(-3.7153642009951775), y=np.float64(-16.018707112003735), z=100.0, module_id=0, track_id=2, extra={}), Hit(hit_id=11, x=np.float64(-4.785238482244728), y=np.float64(-20.52310850812073), z=133.0, module_id=1, track_id=2, extra={}), Hit(hit_id=12, x=np.float64(-5.855113030463019), y=np.float64(-25.02751021282188), z=166.0, module_id=2, track_id=2, extra={}), Hit(hit_id=13, x=np.float64(-6.924987493366407), y=np.float64(-29.531912154315357), z=199.0, module_id=3, track_id=2, extra={}), Hit(hit_id=14, x=np.float64(-7.994862145886518), y=np.float64(-34.036313962586206), z=232.0, module_id=4, track_id=2, extra={}), Hit(hit_id=15, x=np.float64(-15.944931537693309), y=np.float64(4.476494181091659), z=100.0, module_id=0, track_id=3, extra={}), Hit(hit_id=16, x=np.float64(-20.430589157975916), y=np.float64(5.6965111293435005), z=133.0, module_id=1, track_id=3, extra={}), Hit(hit_id=17, x=np.float64(-24.91624705063514), y=np.float64(6.916527460111776), z=166.0, module_id=2, track_id=3, extra={}), Hit(hit_id=18, x=np.float64(-29.401905539055647), y=np.float64(8.13654315625685), z=199.0, module_id=3, track_id=3, extra={}), Hit(hit_id=19, x=np.float64(-33.88756374035428), y=np.float64(9.356558614215281), z=232.0, module_id=4, track_id=3, extra={})], modules=[Module(module_id=0, z=100.0, lx=50.0, ly=50.0, hit_ids=[0, 5, 10, 15], extra={}), Module(module_id=1, z=133.0, lx=50.0, ly=50.0, hit_ids=[1, 6, 11, 16], extra={}), Module(module_id=2, z=166.0, lx=50.0, ly=50.0, hit_ids=[2, 7, 12, 17], extra={}), Module(module_id=3, z=199.0, lx=50.0, ly=50.0, hit_ids=[3, 8, 13, 18], extra={}), Module(module_id=4, z=232.0, lx=50.0, ly=50.0, hit_ids=[4, 9, 14, 19], extra={})], metadata={'generator': 'StateEventGenerator', 'geometry_class': 'PlaneGeometry', 'n_modules': 5, 'z_positions': [100.0, 133.0, 166.0, 199.0, 232.0], 'module_ids': [0, 1, 2, 3, 4], 'phi_min': -0.2, 'phi_max': 0.2, 'theta_min': -0.2, 'theta_max': 0.2, 'events': 1, 'n_particles': [4], 'measurement_error': 0.0, 'collision_noise': 1e-08}),
#   'reco_tracks': [Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}),
#    Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}),
#    Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={}),
#    Track(track_id=3, pv_id=0, hit_ids=[15, 16, 17, 18, 19], extra={})],
#   'true_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14),
#    (15, 16),
#    (16, 17),
#    (17, 18),
#    (18, 19)],
#   'reco_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14),
#    (15, 16),
#    (16, 17),
#    (17, 18),
#    (18, 19)],
#   'matches': [Match(best_truth_id=0, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=0, is_clone=False),
#    Match(best_truth_id=1, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=1, is_clone=False),
#    Match(best_truth_id=2, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=2, is_clone=False),
#    Match(best_truth_id=3, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=3, is_clone=False)],
#   'metrics': {'efficiency': 1.0,
#    'ghost_rate': 0.0,
#    'clone_fraction': 0.0,
#    'mean_purity': 1.0,
#    'hit_efficiency': 1.0,
#    'n_candidates': 4,
#    'n_accepted': 4,
#    'n_ghosts': 0,
#    'n_clones': 0,
#    'n_primary': 4,
#    'n_reconstructible': 4,
#    'n_matched': 4},
#   'ham': <lhcb_velo_toy.solvers.hamiltonians.fast.SimpleHamiltonianFast at 0x7fccd45ce960>,
#   'x': array([0.90909091, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.90909091, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.90909091, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.90909091, 1.27272727, 0.4       , 0.4       , 0.4       ,
#          0.4       , 1.27272727, 0.4       , 0.4       , 0.4       ,
#          0.4       , 1.27272727, 0.4       , 0.4       , 0.4       ,
#          0.4       , 1.27272727, 1.27272727, 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.90909091, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.90909091, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.90909091, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.90909091])},
#  {'event_id': 3,
#   'n_tracks_true': 5,
#   'n_tracks_reco': 5,
#   'event': Event(detector_geometry=PlaneGeometry(module_id=[0, 1, 2, 3, 4], lx=[50.0, 50.0, 50.0, 50.0, 50.0], ly=[50.0, 50.0, 50.0, 50.0, 50.0], z=[100.0, 133.0, 166.0, 199.0, 232.0]), primary_vertices=[PrimaryVertex(pv_id=0, x=0.08942307319141318, y=-0.0959830520821393, z=79.97771015872782, track_ids=[0, 1, 2, 3, 4], extra={})], tracks=[Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}), Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}), Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={}), Track(track_id=3, pv_id=0, hit_ids=[15, 16, 17, 18, 19], extra={}), Track(track_id=4, pv_id=0, hit_ids=[20, 21, 22, 23, 24], extra={})], hits=[Hit(hit_id=0, x=np.float64(1.0630891333254797), y=np.float64(-0.5128970626111162), z=100.0, module_id=0, track_id=0, extra={}), Hit(hit_id=1, x=np.float64(2.667849943245861), y=np.float64(-1.200039130686614), z=133.0, module_id=1, track_id=0, extra={}), Hit(hit_id=2, x=np.float64(4.272610580440846), y=np.float64(-1.8871812366834644), z=166.0, module_id=2, track_id=0, extra={}), Hit(hit_id=3, x=np.float64(5.877371289674004), y=np.float64(-2.574323477342616), z=199.0, module_id=3, track_id=0, extra={}), Hit(hit_id=4, x=np.float64(7.482131777831771), y=np.float64(-3.2614661545556602), z=232.0, module_id=4, track_id=0, extra={}), Hit(hit_id=5, x=np.float64(-3.307071573322344), y=np.float64(0.3738146867628198), z=100.0, module_id=0, track_id=1, extra={}), Hit(hit_id=6, x=np.float64(-8.90504951127689), y=np.float64(1.1481186016668128), z=133.0, module_id=1, track_id=1, extra={}), Hit(hit_id=7, x=np.float64(-14.503027766895464), y=np.float64(1.9224218880047408), z=166.0, module_id=2, track_id=1, extra={}), Hit(hit_id=8, x=np.float64(-20.101005719842135), y=np.float64(2.6967259565057904), z=199.0, module_id=3, track_id=1, extra={}), Hit(hit_id=9, x=np.float64(-25.698983900273902), y=np.float64(3.4710303073438142), z=232.0, module_id=4, track_id=1, extra={}), Hit(hit_id=10, x=np.float64(1.1017646408189734), y=np.float64(-1.4430811093861549), z=100.0, module_id=0, track_id=2, extra={}), Hit(hit_id=11, x=np.float64(2.7702678735799293), y=np.float64(-3.663318386838964), z=133.0, module_id=1, track_id=2, extra={}), Hit(hit_id=12, x=np.float64(4.4387717656517385), y=np.float64(-5.883555528482877), z=166.0, module_id=2, track_id=2, extra={}), Hit(hit_id=13, x=np.float64(6.107276040867567), y=np.float64(-8.10379243478566), z=199.0, module_id=3, track_id=2, extra={}), Hit(hit_id=14, x=np.float64(7.775780088929294), y=np.float64(-10.324028968205896), z=232.0, module_id=4, track_id=2, extra={}), Hit(hit_id=15, x=np.float64(-1.4729656195349), y=np.float64(-2.322719528495942), z=100.0, module_id=0, track_id=3, extra={}), Hit(hit_id=16, x=np.float64(-4.048037144687931), y=np.float64(-5.9927443518014645), z=133.0, module_id=1, track_id=3, extra={}), Hit(hit_id=17, x=np.float64(-6.623108774683011), y=np.float64(-9.662769036608605), z=166.0, module_id=2, track_id=3, extra={}), Hit(hit_id=18, x=np.float64(-9.198180103476657), y=np.float64(-13.332794077075196), z=199.0, module_id=3, track_id=3, extra={}), Hit(hit_id=19, x=np.float64(-11.77325172394355), y=np.float64(-17.00281927791889), z=232.0, module_id=4, track_id=3, extra={}), Hit(hit_id=20, x=np.float64(-3.8178560443878284), y=np.float64(0.553756418709583), z=100.0, module_id=0, track_id=4, extra={}), Hit(hit_id=21, x=np.float64(-10.257689106965568), y=np.float64(1.6246333351939874), z=133.0, module_id=1, track_id=4, extra={}), Hit(hit_id=22, x=np.float64(-16.69752259750369), y=np.float64(2.6955102918278104), z=166.0, module_id=2, track_id=4, extra={}), Hit(hit_id=23, x=np.float64(-23.1373563976887), y=np.float64(3.766387059812872), z=199.0, module_id=3, track_id=4, extra={}), Hit(hit_id=24, x=np.float64(-29.577190079062362), y=np.float64(4.83726391527439), z=232.0, module_id=4, track_id=4, extra={})], modules=[Module(module_id=0, z=100.0, lx=50.0, ly=50.0, hit_ids=[0, 5, 10, 15, 20], extra={}), Module(module_id=1, z=133.0, lx=50.0,  ...
#   'reco_tracks': [Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}),
#    Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}),
#    Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={}),
#    Track(track_id=3, pv_id=0, hit_ids=[15, 16, 17, 18, 19], extra={}),
#    Track(track_id=4, pv_id=0, hit_ids=[20, 21, 22, 23, 24], extra={})],
#   'true_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14),
#    (15, 16),
#    (16, 17),
#    (17, 18),
#    (18, 19),
#    (20, 21),
#    (21, 22),
#    (22, 23),
#    (23, 24)],
#   'reco_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14),
#    (15, 16),
#    (16, 17),
#    (17, 18),
#    (18, 19),
#    (20, 21),
#    (21, 22),
#    (22, 23),
#    (23, 24)],
#   'matches': [Match(best_truth_id=0, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=0, is_clone=False),
#    Match(best_truth_id=1, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=1, is_clone=False),
#    Match(best_truth_id=2, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=2, is_clone=False),
#    Match(best_truth_id=3, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=3, is_clone=False),
#    Match(best_truth_id=4, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=4, is_clone=False)],
#   'metrics': {'efficiency': 1.0,
#    'ghost_rate': 0.0,
#    'clone_fraction': 0.0,
#    'mean_purity': 1.0,
#    'hit_efficiency': 1.0,
#    'n_candidates': 5,
#    'n_accepted': 5,
#    'n_ghosts': 0,
#    'n_clones': 0,
#    'n_primary': 5,
#    'n_reconstructible': 5,
#    'n_matched': 5},
#   'ham': <lhcb_velo_toy.solvers.hamiltonians.fast.SimpleHamiltonianFast at 0x7fccd46d40e0>,
#   'x': array([0.90909091, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.90909091, 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.90909091, 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.90909091, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.4       , 0.90909091,
#          1.27272727, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 1.27272727, 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 1.27272727, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.4       , 1.27272727,
#          1.27272727, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 1.27272727, 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 1.27272727, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.4       , 1.27272727,
#          0.90909091, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.90909091, 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.90909091, 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.90909091, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.4       , 0.90909091])},
#  {'event_id': 4,
#   'n_tracks_true': 6,
#   'n_tracks_reco': 2,
#   'event': Event(detector_geometry=PlaneGeometry(module_id=[0, 1, 2, 3, 4], lx=[50.0, 50.0, 50.0, 50.0, 50.0], ly=[50.0, 50.0, 50.0, 50.0, 50.0], z=[100.0, 133.0, 166.0, 199.0, 232.0]), primary_vertices=[PrimaryVertex(pv_id=0, x=0.03091591825518456, y=-0.03826788433967583, z=-79.1014142176465, track_ids=[0, 1, 2, 3, 4, 5], extra={})], tracks=[Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2], extra={}), Track(track_id=1, pv_id=0, hit_ids=[3, 4, 5, 6, 7], extra={}), Track(track_id=2, pv_id=0, hit_ids=[8, 9, 10], extra={}), Track(track_id=3, pv_id=0, hit_ids=[11, 12, 13], extra={}), Track(track_id=4, pv_id=0, hit_ids=[14, 15, 16], extra={}), Track(track_id=5, pv_id=0, hit_ids=[17, 18, 19, 20, 21], extra={})], hits=[Hit(hit_id=0, x=np.float64(32.38089019360686), y=np.float64(-12.131185123076177), z=100.0, module_id=0, track_id=0, extra={}), Hit(hit_id=1, x=np.float64(38.341475241894024), y=np.float64(-14.359342961750524), z=133.0, module_id=1, track_id=0, extra={}), Hit(hit_id=2, x=np.float64(44.30205968461971), y=np.float64(-16.58750109095636), z=166.0, module_id=2, track_id=0, extra={}), Hit(hit_id=3, x=np.float64(-24.41783004498187), y=np.float64(-12.886747385353809), z=100.0, module_id=0, track_id=1, extra={}), Hit(hit_id=4, x=np.float64(-28.92258873103941), y=np.float64(-15.254120375318942), z=133.0, module_id=1, track_id=1, extra={}), Hit(hit_id=5, x=np.float64(-33.427347570717735), y=np.float64(-17.621493625249936), z=166.0, module_id=2, track_id=1, extra={}), Hit(hit_id=6, x=np.float64(-37.93210564825314), y=np.float64(-19.98886695181869), z=199.0, module_id=3, track_id=1, extra={}), Hit(hit_id=7, x=np.float64(-42.43686366088899), y=np.float64(-22.35624013557839), z=232.0, module_id=4, track_id=1, extra={}), Hit(hit_id=8, x=np.float64(-32.25610890233551), y=np.float64(-9.852873633393253), z=100.0, module_id=0, track_id=2, extra={}), Hit(hit_id=9, x=np.float64(-38.20509467731373), y=np.float64(-11.661246045891616), z=133.0, module_id=1, track_id=2, extra={}), Hit(hit_id=10, x=np.float64(-44.15408073517135), y=np.float64(-13.469618417884268), z=166.0, module_id=2, track_id=2, extra={}), Hit(hit_id=11, x=np.float64(-35.83311491837874), y=np.float64(-28.256926524516782), z=100.0, module_id=0, track_id=3, extra={}), Hit(hit_id=12, x=np.float64(-42.4411752310004), y=np.float64(-33.4563037399636), z=133.0, module_id=1, track_id=3, extra={}), Hit(hit_id=13, x=np.float64(-49.04923524988001), y=np.float64(-38.65568073953344), z=166.0, module_id=2, track_id=3, extra={}), Hit(hit_id=14, x=np.float64(-15.308013295632257), y=np.float64(33.851151320860744), z=100.0, module_id=0, track_id=4, extra={}), Hit(hit_id=15, x=np.float64(-18.134259249445737), y=np.float64(40.0953837079929), z=133.0, module_id=1, track_id=4, extra={}), Hit(hit_id=16, x=np.float64(-20.9605052767713), y=np.float64(46.33961657771843), z=166.0, module_id=2, track_id=4, extra={}), Hit(hit_id=17, x=np.float64(-12.730543025832725), y=np.float64(-18.700685201307653), z=100.0, module_id=0, track_id=5, extra={}), Hit(hit_id=18, x=np.float64(-15.081882681579042), y=np.float64(-22.139294847382036), z=133.0, module_id=1, track_id=5, extra={}), Hit(hit_id=19, x=np.float64(-17.433222245603474), y=np.float64(-25.577904959099904), z=166.0, module_id=2, track_id=5, extra={}), Hit(hit_id=20, x=np.float64(-19.784561626820782), y=np.float64(-29.016515043917604), z=199.0, module_id=3, track_id=5, extra={}), Hit(hit_id=21, x=np.float64(-22.135900988274198), y=np.float64(-32.45512507825616), z=232.0, module_id=4, track_id=5, extra={})], modules=[Module(module_id=0, z=100.0, lx=50.0, ly=50.0, hit_ids=[0, 3, 8, 11, 14, 17], extra={}), Module(module_id=1, z=133.0, lx=50.0, ly=50.0, hit_ids=[1, 4, 9, 12, 15, 18], extra={}), Module(module_id=2, z=166.0, lx=50.0, ly=50.0, hit_ids=[2, 5, 10, 13, 16, 19], extra={}), Module(module_id=3, z=199.0, lx=50.0, ly=50.0, hit_ids=[6, 20], extra={}), Module(module_id=4, z=232.0, lx=50.0, ly=50.0, hit_ids=[7, 21], extra={})], metadata={'generator': 'StateEventG ...
#   'reco_tracks': [Track(track_id=0, pv_id=0, hit_ids=[3, 4, 5, 6, 7], extra={}),
#    Track(track_id=1, pv_id=0, hit_ids=[17, 18, 19, 20, 21], extra={})],
#   'true_segments': [(0, 1),
#    (1, 2),
#    (3, 4),
#    (4, 5),
#    (5, 6),
#    (6, 7),
#    (8, 9),
#    (9, 10),
#    (11, 12),
#    (12, 13),
#    (14, 15),
#    (15, 16),
#    (17, 18),
#    (18, 19),
#    (19, 20),
#    (20, 21)],
#   'reco_segments': [(3, 4),
#    (4, 5),
#    (5, 6),
#    (6, 7),
#    (17, 18),
#    (18, 19),
#    (19, 20),
#    (20, 21)],
#   'matches': [Match(best_truth_id=1, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=1, is_clone=False),
#    Match(best_truth_id=5, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=5, is_clone=False)],
#   'metrics': {'efficiency': 0.3333333333333333,
#    'ghost_rate': 0.0,
#    'clone_fraction': 0.0,
#    'mean_purity': 1.0,
#    'hit_efficiency': 1.0,
#    'n_candidates': 2,
#    'n_accepted': 2,
#    'n_ghosts': 0,
#    'n_clones': 0,
#    'n_primary': 2,
#    'n_reconstructible': 6,
#    'n_matched': 2},
#   'ham': <lhcb_velo_toy.solvers.hamiltonians.fast.SimpleHamiltonianFast at 0x7fccd425cce0>,
#   'x': array([0.66666667, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.90909091, 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.4       , 0.66666667,
#          0.4       , 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.66666667, 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.66666667, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.90909091, 0.66666667, 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 1.27272727, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.66666667, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.66666667, 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.4       , 0.66666667,
#          0.4       , 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 1.27272727, 0.4       , 0.4       , 1.27272727,
#          0.4       , 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 1.27272727, 0.90909091,
#          0.4       , 0.4       , 0.90909091])},
#  {'event_id': 5,
#   'n_tracks_true': 3,
#   'n_tracks_reco': 3,
#   'event': Event(detector_geometry=PlaneGeometry(module_id=[0, 1, 2, 3, 4], lx=[50.0, 50.0, 50.0, 50.0, 50.0], ly=[50.0, 50.0, 50.0, 50.0, 50.0], z=[100.0, 133.0, 166.0, 199.0, 232.0]), primary_vertices=[PrimaryVertex(pv_id=0, x=0.1107671832046545, y=-0.0717238195861024, z=98.35079478096263, track_ids=[0, 1, 2], extra={})], tracks=[Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}), Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}), Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={})], hits=[Hit(hit_id=0, x=np.float64(0.22541930057867404), y=np.float64(-0.2345164170308674), z=100.0, module_id=0, track_id=0, extra={}), Hit(hit_id=1, x=np.float64(2.519566398768758), y=np.float64(-3.4919378326117845), z=133.0, module_id=1, track_id=0, extra={}), Hit(hit_id=2, x=np.float64(4.813713020232956), y=np.float64(-6.749359067447317), z=166.0, module_id=2, track_id=0, extra={}), Hit(hit_id=3, x=np.float64(7.107859803865096), y=np.float64(-10.00678020114276), z=199.0, module_id=3, track_id=0, extra={}), Hit(hit_id=4, x=np.float64(9.402006737726328), y=np.float64(-13.26420158456763), z=232.0, module_id=4, track_id=0, extra={}), Hit(hit_id=5, x=np.float64(0.39142585035093114), y=np.float64(-0.3603140307085949), z=100.0, module_id=0, track_id=1, extra={}), Hit(hit_id=6, x=np.float64(6.007303738929886), y=np.float64(-6.134899992648943), z=133.0, module_id=1, track_id=1, extra={}), Hit(hit_id=7, x=np.float64(11.623181341047143), y=np.float64(-11.909485558134044), z=166.0, module_id=2, track_id=1, extra={}), Hit(hit_id=8, x=np.float64(17.239058528083973), y=np.float64(-17.684070998244103), z=199.0, module_id=3, track_id=1, extra={}), Hit(hit_id=9, x=np.float64(22.85493587269953), y=np.float64(-23.45865656720097), z=232.0, module_id=4, track_id=1, extra={}), Hit(hit_id=10, x=np.float64(0.43603189607820675), y=np.float64(0.10309563716242696), z=100.0, module_id=0, track_id=2, extra={}), Hit(hit_id=11, x=np.float64(6.944460781501676), y=np.float64(3.601169479809965), z=133.0, module_id=1, track_id=2, extra={}), Hit(hit_id=12, x=np.float64(13.452889505636746), y=np.float64(7.099243166793709), z=166.0, module_id=2, track_id=2, extra={}), Hit(hit_id=13, x=np.float64(19.9613180550143), y=np.float64(10.597316994181199), z=199.0, module_id=3, track_id=2, extra={}), Hit(hit_id=14, x=np.float64(26.469746259946433), y=np.float64(14.095391054647072), z=232.0, module_id=4, track_id=2, extra={})], modules=[Module(module_id=0, z=100.0, lx=50.0, ly=50.0, hit_ids=[0, 5, 10], extra={}), Module(module_id=1, z=133.0, lx=50.0, ly=50.0, hit_ids=[1, 6, 11], extra={}), Module(module_id=2, z=166.0, lx=50.0, ly=50.0, hit_ids=[2, 7, 12], extra={}), Module(module_id=3, z=199.0, lx=50.0, ly=50.0, hit_ids=[3, 8, 13], extra={}), Module(module_id=4, z=232.0, lx=50.0, ly=50.0, hit_ids=[4, 9, 14], extra={})], metadata={'generator': 'StateEventGenerator', 'geometry_class': 'PlaneGeometry', 'n_modules': 5, 'z_positions': [100.0, 133.0, 166.0, 199.0, 232.0], 'module_ids': [0, 1, 2, 3, 4], 'phi_min': -0.2, 'phi_max': 0.2, 'theta_min': -0.2, 'theta_max': 0.2, 'events': 1, 'n_particles': [3], 'measurement_error': 0.0, 'collision_noise': 1e-08}),
#   'reco_tracks': [Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}),
#    Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}),
#    Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={})],
#   'true_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14)],
#   'reco_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14)],
#   'matches': [Match(best_truth_id=0, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=0, is_clone=False),
#    Match(best_truth_id=1, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=1, is_clone=False),
#    Match(best_truth_id=2, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=2, is_clone=False)],
#   'metrics': {'efficiency': 1.0,
#    'ghost_rate': 0.0,
#    'clone_fraction': 0.0,
#    'mean_purity': 1.0,
#    'hit_efficiency': 1.0,
#    'n_candidates': 3,
#    'n_accepted': 3,
#    'n_ghosts': 0,
#    'n_clones': 0,
#    'n_primary': 3,
#    'n_reconstructible': 3,
#    'n_matched': 3},
#   'ham': <lhcb_velo_toy.solvers.hamiltonians.fast.SimpleHamiltonianFast at 0x7fccd52bc4a0>,
#   'x': array([0.90909091, 0.4       , 0.4       , 0.4       , 0.90909091,
#          0.4       , 0.4       , 0.4       , 0.90909091, 1.27272727,
#          0.4       , 0.4       , 0.4       , 1.27272727, 0.4       ,
#          0.4       , 0.4       , 1.27272727, 1.27272727, 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.4       , 0.4       ,
#          0.4       , 1.27272727, 0.90909091, 0.4       , 0.4       ,
#          0.4       , 0.90909091, 0.4       , 0.4       , 0.4       ,
#          0.90909091])},
#  {'event_id': 6,
#   'n_tracks_true': 4,
#   'n_tracks_reco': 3,
#   'event': Event(detector_geometry=PlaneGeometry(module_id=[0, 1, 2, 3, 4], lx=[50.0, 50.0, 50.0, 50.0, 50.0], ly=[50.0, 50.0, 50.0, 50.0, 50.0], z=[100.0, 133.0, 166.0, 199.0, 232.0]), primary_vertices=[PrimaryVertex(pv_id=0, x=-0.017209958849026413, y=-0.016936552616288108, z=105.98279945143236, track_ids=[0, 1, 2, 3], extra={})], tracks=[Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}), Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}), Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={}), Track(track_id=3, pv_id=0, hit_ids=[15, 16, 17, 18, 19], extra={})], hits=[Hit(hit_id=0, x=np.float64(0.1768035049713612), y=np.float64(0.19113479223612434), z=100.0, module_id=0, track_id=0, extra={}), Hit(hit_id=1, x=np.float64(-0.8933380307302157), y=np.float64(-0.956547714293204), z=133.0, module_id=1, track_id=0, extra={}), Hit(hit_id=2, x=np.float64(-1.9634791308532544), y=np.float64(-2.1042303048569604), z=166.0, module_id=2, track_id=0, extra={}), Hit(hit_id=3, x=np.float64(-3.0336205021811127), y=np.float64(-3.2519127710537465), z=199.0, module_id=3, track_id=0, extra={}), Hit(hit_id=4, x=np.float64(-4.10376234136381), y=np.float64(-4.399595482807452), z=232.0, module_id=4, track_id=0, extra={}), Hit(hit_id=5, x=np.float64(-0.3976930232529854), y=np.float64(0.940156139684987), z=100.0, module_id=0, track_id=1, extra={}), Hit(hit_id=6, x=np.float64(1.7009800923992666), y=np.float64(-4.338987638233401), z=133.0, module_id=1, track_id=1, extra={}), Hit(hit_id=7, x=np.float64(3.79965256369577), y=np.float64(-9.618131486961344), z=166.0, module_id=2, track_id=1, extra={}), Hit(hit_id=8, x=np.float64(5.898325123418118), y=np.float64(-14.897275549631381), z=199.0, module_id=3, track_id=1, extra={}), Hit(hit_id=9, x=np.float64(7.996998338657602), y=np.float64(-20.17641964889329), z=232.0, module_id=4, track_id=1, extra={}), Hit(hit_id=10, x=np.float64(-1.0234644635514134), y=np.float64(-0.3322424153766495), z=100.0, module_id=0, track_id=2, extra={}), Hit(hit_id=11, x=np.float64(4.5268466086275065), y=np.float64(1.4069257163284508), z=133.0, module_id=1, track_id=2, extra={}), Hit(hit_id=12, x=np.float64(10.077157312358263), y=np.float64(3.1460941004194023), z=166.0, module_id=2, track_id=2, extra={}), Hit(hit_id=13, x=np.float64(15.627468889460392), y=np.float64(4.885263286685878), z=199.0, module_id=3, track_id=2, extra={}), Hit(hit_id=14, x=np.float64(21.177780459005618), y=np.float64(6.6244321138410545), z=232.0, module_id=4, track_id=2, extra={}), Hit(hit_id=15, x=np.float64(-0.9415677767250126), y=np.float64(-0.3260486174844214), z=100.0, module_id=0, track_id=3, extra={}), Hit(hit_id=16, x=np.float64(4.157016889451208), y=np.float64(1.378955877040303), z=133.0, module_id=1, track_id=3, extra={}), Hit(hit_id=17, x=np.float64(9.255601523324806), y=np.float64(3.083960311412958), z=166.0, module_id=2, track_id=3, extra={}), Hit(hit_id=18, x=np.float64(14.354185901100138), y=np.float64(4.788964275699801), z=199.0, module_id=3, track_id=3, extra={}), Hit(hit_id=19, x=np.float64(19.452770519674782), y=np.float64(6.493968015962681), z=232.0, module_id=4, track_id=3, extra={})], modules=[Module(module_id=0, z=100.0, lx=50.0, ly=50.0, hit_ids=[0, 5, 10, 15], extra={}), Module(module_id=1, z=133.0, lx=50.0, ly=50.0, hit_ids=[1, 6, 11, 16], extra={}), Module(module_id=2, z=166.0, lx=50.0, ly=50.0, hit_ids=[2, 7, 12, 17], extra={}), Module(module_id=3, z=199.0, lx=50.0, ly=50.0, hit_ids=[3, 8, 13, 18], extra={}), Module(module_id=4, z=232.0, lx=50.0, ly=50.0, hit_ids=[4, 9, 14, 19], extra={})], metadata={'generator': 'StateEventGenerator', 'geometry_class': 'PlaneGeometry', 'n_modules': 5, 'z_positions': [100.0, 133.0, 166.0, 199.0, 232.0], 'module_ids': [0, 1, 2, 3, 4], 'phi_min': -0.2, 'phi_max': 0.2, 'theta_min': -0.2, 'theta_max': 0.2, 'events': 1, 'n_particles': [4], 'measurement_error': 0.0, 'collision_noise': 1e-08}),
#   'reco_tracks': [Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}),
#    Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}),
#    Track(track_id=2, pv_id=0, hit_ids=[10, 15, 11, 16, 12, 17, 13, 18, 14, 19], extra={})],
#   'true_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14),
#    (15, 16),
#    (16, 17),
#    (17, 18),
#    (18, 19)],
#   'reco_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 15),
#    (15, 11),
#    (11, 16),
#    (16, 12),
#    (12, 17),
#    (17, 13),
#    (13, 18),
#    (18, 14),
#    (14, 19)],
#   'matches': [Match(best_truth_id=0, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=0, is_clone=False),
#    Match(best_truth_id=1, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=1, is_clone=False),
#    Match(best_truth_id=2, rec_hits=10, truth_hits=5, correct_hits=5, purity=0.5, hit_efficiency=1.0, candidate=True, accepted=False, truth_id=None, is_clone=False)],
#   'metrics': {'efficiency': 0.5,
#    'ghost_rate': 0.3333333333333333,
#    'clone_fraction': 0.0,
#    'mean_purity': 1.0,
#    'hit_efficiency': 1.0,
#    'n_candidates': 3,
#    'n_accepted': 2,
#    'n_ghosts': 1,
#    'n_clones': 0,
#    'n_primary': 2,
#    'n_reconstructible': 4,
#    'n_matched': 2},
#   'ham': <lhcb_velo_toy.solvers.hamiltonians.fast.SimpleHamiltonianFast at 0x7fccd5325730>,
#   'x': array([0.90909091, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.90909091, 0.4       , 0.4       , 0.4       , 0.4       ,
#          1.20622568, 1.20622568, 0.4       , 0.4       , 1.20622568,
#          1.20622568, 1.27272727, 0.4       , 0.4       , 0.4       ,
#          0.4       , 1.27272727, 0.4       , 0.4       , 0.4       ,
#          0.4       , 2.0155642 , 0.4       , 0.4       , 0.4       ,
#          0.4       , 2.0155642 , 1.27272727, 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.62645914, 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.62645914, 0.90909091, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.90909091, 0.4       ,
#          0.4       , 0.4       , 0.4       , 1.05058366, 0.4       ,
#          0.4       , 0.4       , 0.4       , 1.05058366])},
#  {'event_id': 7,
#   'n_tracks_true': 5,
#   'n_tracks_reco': 5,
#   'event': Event(detector_geometry=PlaneGeometry(module_id=[0, 1, 2, 3, 4], lx=[50.0, 50.0, 50.0, 50.0, 50.0], ly=[50.0, 50.0, 50.0, 50.0, 50.0], z=[100.0, 133.0, 166.0, 199.0, 232.0]), primary_vertices=[PrimaryVertex(pv_id=0, x=-0.09583691086440686, y=-0.0034913298831329566, z=-8.50218647402343, track_ids=[0, 1, 2, 3, 4], extra={})], tracks=[Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}), Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}), Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={}), Track(track_id=3, pv_id=0, hit_ids=[15, 16, 17, 18, 19], extra={}), Track(track_id=4, pv_id=0, hit_ids=[20, 21, 22, 23, 24], extra={})], hits=[Hit(hit_id=0, x=np.float64(11.228549995613024), y=np.float64(-13.658888860942762), z=100.0, module_id=0, track_id=0, extra={}), Hit(hit_id=1, x=np.float64(14.672764184827864), y=np.float64(-17.812059876097926), z=133.0, module_id=1, track_id=0, extra={}), Hit(hit_id=2, x=np.float64(18.116978429105878), y=np.float64(-21.96523061968614), z=166.0, module_id=2, track_id=0, extra={}), Hit(hit_id=3, x=np.float64(21.561193378234478), y=np.float64(-26.118401280673705), z=199.0, module_id=3, track_id=0, extra={}), Hit(hit_id=4, x=np.float64(25.005408507612334), y=np.float64(-30.271571877312468), z=232.0, module_id=4, track_id=0, extra={}), Hit(hit_id=5, x=np.float64(-16.529084230456345), y=np.float64(7.3340291943747165), z=100.0, module_id=0, track_id=1, extra={}), Hit(hit_id=6, x=np.float64(-21.527113980515864), y=np.float64(9.565671672216487), z=133.0, module_id=1, track_id=1, extra={}), Hit(hit_id=7, x=np.float64(-26.52514389004041), y=np.float64(11.797314530319028), z=166.0, module_id=2, track_id=1, extra={}), Hit(hit_id=8, x=np.float64(-31.52317389710217), y=np.float64(14.028957117833368), z=199.0, module_id=3, track_id=1, extra={}), Hit(hit_id=9, x=np.float64(-36.52120374410239), y=np.float64(16.260599943295585), z=232.0, module_id=4, track_id=1, extra={}), Hit(hit_id=10, x=np.float64(-15.478373643970189), y=np.float64(13.321618281305804), z=100.0, module_id=0, track_id=2, extra={}), Hit(hit_id=11, x=np.float64(-20.156838301754497), y=np.float64(17.374335124715007), z=133.0, module_id=1, track_id=2, extra={}), Hit(hit_id=12, x=np.float64(-24.835302330135093), y=np.float64(21.42705201610153), z=166.0, module_id=2, track_id=2, extra={}), Hit(hit_id=13, x=np.float64(-29.51376584726318), y=np.float64(25.479769115885677), z=199.0, module_id=3, track_id=2, extra={}), Hit(hit_id=14, x=np.float64(-34.19222932131222), y=np.float64(29.53248633635507), z=232.0, module_id=4, track_id=2, extra={}), Hit(hit_id=15, x=np.float64(-18.81318938379512), y=np.float64(-16.57689768195375), z=100.0, module_id=0, track_id=3, extra={}), Hit(hit_id=16, x=np.float64(-24.50590939623317), y=np.float64(-21.61755522870776), z=133.0, module_id=1, track_id=3, extra={}), Hit(hit_id=17, x=np.float64(-30.198629613946576), y=np.float64(-26.658212758467975), z=166.0, module_id=2, track_id=3, extra={}), Hit(hit_id=18, x=np.float64(-35.89134947591176), y=np.float64(-31.698870507565893), z=199.0, module_id=3, track_id=3, extra={}), Hit(hit_id=19, x=np.float64(-41.58406877638539), y=np.float64(-36.739527889065435), z=232.0, module_id=4, track_id=3, extra={}), Hit(hit_id=20, x=np.float64(-21.28166778064372), y=np.float64(-16.9532877065267), z=100.0, module_id=0, track_id=4, extra={}), Hit(hit_id=21, x=np.float64(-27.725154452564876), y=np.float64(-22.108421407050727), z=133.0, module_id=1, track_id=4, extra={}), Hit(hit_id=22, x=np.float64(-34.16864129573513), y=np.float64(-27.263555109732557), z=166.0, module_id=2, track_id=4, extra={}), Hit(hit_id=23, x=np.float64(-40.61212843927517), y=np.float64(-32.41868919279364), z=199.0, module_id=3, track_id=4, extra={}), Hit(hit_id=24, x=np.float64(-47.055615366452855), y=np.float64(-37.57382285990989), z=232.0, module_id=4, track_id=4, extra={})], modules=[Module(module_id=0, z=100.0, lx=50.0, ly=50.0, hit_ids=[0, 5, 10, 15, 20], extra={}), Module(module_id=1, ...
#   'reco_tracks': [Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}),
#    Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}),
#    Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={}),
#    Track(track_id=3, pv_id=0, hit_ids=[15, 16, 17, 18, 19], extra={}),
#    Track(track_id=4, pv_id=0, hit_ids=[20, 21, 22, 23, 24], extra={})],
#   'true_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14),
#    (15, 16),
#    (16, 17),
#    (17, 18),
#    (18, 19),
#    (20, 21),
#    (21, 22),
#    (22, 23),
#    (23, 24)],
#   'reco_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14),
#    (15, 16),
#    (16, 17),
#    (17, 18),
#    (18, 19),
#    (20, 21),
#    (21, 22),
#    (22, 23),
#    (23, 24)],
#   'matches': [Match(best_truth_id=0, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=0, is_clone=False),
#    Match(best_truth_id=1, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=1, is_clone=False),
#    Match(best_truth_id=2, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=2, is_clone=False),
#    Match(best_truth_id=3, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=3, is_clone=False),
#    Match(best_truth_id=4, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=4, is_clone=False)],
#   'metrics': {'efficiency': 1.0,
#    'ghost_rate': 0.0,
#    'clone_fraction': 0.0,
#    'mean_purity': 1.0,
#    'hit_efficiency': 1.0,
#    'n_candidates': 5,
#    'n_accepted': 5,
#    'n_ghosts': 0,
#    'n_clones': 0,
#    'n_primary': 5,
#    'n_reconstructible': 5,
#    'n_matched': 5},
#   'ham': <lhcb_velo_toy.solvers.hamiltonians.fast.SimpleHamiltonianFast at 0x7fccd56f7350>,
#   'x': array([0.90909091, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.90909091, 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.90909091, 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.90909091, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.4       , 0.90909091,
#          1.27272727, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 1.27272727, 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 1.27272727, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.4       , 1.27272727,
#          1.27272727, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 1.27272727, 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 1.27272727, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.4       , 1.27272727,
#          0.90909091, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.90909091, 0.4       , 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.90909091, 0.4       , 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.90909091, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.4       , 0.90909091])},
#  {'event_id': 8,
#   'n_tracks_true': 2,
#   'n_tracks_reco': 2,
#   'event': Event(detector_geometry=PlaneGeometry(module_id=[0, 1, 2, 3, 4], lx=[50.0, 50.0, 50.0, 50.0, 50.0], ly=[50.0, 50.0, 50.0, 50.0, 50.0], z=[100.0, 133.0, 166.0, 199.0, 232.0]), primary_vertices=[PrimaryVertex(pv_id=0, x=-0.07637340212000811, y=-0.09725461840812777, z=31.62862346453057, track_ids=[0, 1], extra={})], tracks=[Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}), Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={})], hits=[Hit(hit_id=0, x=np.float64(-10.42718997401772), y=np.float64(8.802571142046144), z=100.0, module_id=0, track_id=0, extra={}), Hit(hit_id=1, x=np.float64(-15.423096196985727), y=np.float64(13.098144206609543), z=133.0, module_id=1, track_id=0, extra={}), Hit(hit_id=2, x=np.float64(-20.41900181749271), y=np.float64(17.393717110247625), z=166.0, module_id=2, track_id=0, extra={}), Hit(hit_id=3, x=np.float64(-25.41490709430502), y=np.float64(21.68928979619886), z=199.0, module_id=3, track_id=0, extra={}), Hit(hit_id=4, x=np.float64(-30.410812038275903), y=np.float64(25.984862846234826), z=232.0, module_id=4, track_id=0, extra={}), Hit(hit_id=5, x=np.float64(5.3439834569621585), y=np.float64(-1.4596929846201911), z=100.0, module_id=0, track_id=1, extra={}), Hit(hit_id=6, x=np.float64(7.960162956436983), y=np.float64(-2.1172850207734717), z=133.0, module_id=1, track_id=1, extra={}), Hit(hit_id=7, x=np.float64(10.576341899709051), y=np.float64(-2.7748774347392384), z=166.0, module_id=2, track_id=1, extra={}), Hit(hit_id=8, x=np.float64(13.19252126482834), y=np.float64(-3.4324701798114763), z=199.0, module_id=3, track_id=1, extra={}), Hit(hit_id=9, x=np.float64(15.808700845964305), y=np.float64(-4.0900631021137), z=232.0, module_id=4, track_id=1, extra={})], modules=[Module(module_id=0, z=100.0, lx=50.0, ly=50.0, hit_ids=[0, 5], extra={}), Module(module_id=1, z=133.0, lx=50.0, ly=50.0, hit_ids=[1, 6], extra={}), Module(module_id=2, z=166.0, lx=50.0, ly=50.0, hit_ids=[2, 7], extra={}), Module(module_id=3, z=199.0, lx=50.0, ly=50.0, hit_ids=[3, 8], extra={}), Module(module_id=4, z=232.0, lx=50.0, ly=50.0, hit_ids=[4, 9], extra={})], metadata={'generator': 'StateEventGenerator', 'geometry_class': 'PlaneGeometry', 'n_modules': 5, 'z_positions': [100.0, 133.0, 166.0, 199.0, 232.0], 'module_ids': [0, 1, 2, 3, 4], 'phi_min': -0.2, 'phi_max': 0.2, 'theta_min': -0.2, 'theta_max': 0.2, 'events': 1, 'n_particles': [2], 'measurement_error': 0.0, 'collision_noise': 1e-08}),
#   'reco_tracks': [Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}),
#    Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={})],
#   'true_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9)],
#   'reco_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9)],
#   'matches': [Match(best_truth_id=0, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=0, is_clone=False),
#    Match(best_truth_id=1, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=1, is_clone=False)],
#   'metrics': {'efficiency': 1.0,
#    'ghost_rate': 0.0,
#    'clone_fraction': 0.0,
#    'mean_purity': 1.0,
#    'hit_efficiency': 1.0,
#    'n_candidates': 2,
#    'n_accepted': 2,
#    'n_ghosts': 0,
#    'n_clones': 0,
#    'n_primary': 2,
#    'n_reconstructible': 2,
#    'n_matched': 2},
#   'ham': <lhcb_velo_toy.solvers.hamiltonians.fast.SimpleHamiltonianFast at 0x7fccd45190d0>,
#   'x': array([0.90909091, 0.4       , 0.4       , 0.90909091, 1.27272727,
#          0.4       , 0.4       , 1.27272727, 1.27272727, 0.4       ,
#          0.4       , 1.27272727, 0.90909091, 0.4       , 0.4       ,
#          0.90909091])},
#  {'event_id': 9,
#   'n_tracks_true': 4,
#   'n_tracks_reco': 4,
#   'event': Event(detector_geometry=PlaneGeometry(module_id=[0, 1, 2, 3, 4], lx=[50.0, 50.0, 50.0, 50.0, 50.0], ly=[50.0, 50.0, 50.0, 50.0, 50.0], z=[100.0, 133.0, 166.0, 199.0, 232.0]), primary_vertices=[PrimaryVertex(pv_id=0, x=-0.019387953641026856, y=-0.16687178404222883, z=74.5048826965472, track_ids=[0, 1, 2, 3], extra={})], tracks=[Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}), Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}), Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={}), Track(track_id=3, pv_id=0, hit_ids=[15, 16, 17, 18, 19], extra={})], hits=[Hit(hit_id=0, x=np.float64(-1.7095586793467776), y=np.float64(-4.162612943981786), z=100.0, module_id=0, track_id=0, extra={}), Hit(hit_id=1, x=np.float64(-3.897257724955222), y=np.float64(-9.334562382340604), z=133.0, module_id=1, track_id=0, extra={}), Hit(hit_id=2, x=np.float64(-6.084957150719328), y=np.float64(-14.506511472249557), z=166.0, module_id=2, track_id=0, extra={}), Hit(hit_id=3, x=np.float64(-8.272656842117843), y=np.float64(-19.67846106436279), z=199.0, module_id=3, track_id=0, extra={}), Hit(hit_id=4, x=np.float64(-10.460356408015684), y=np.float64(-24.850410525240438), z=232.0, module_id=4, track_id=0, extra={}), Hit(hit_id=5, x=np.float64(-0.13836604594979798), y=np.float64(1.3197924100555183), z=100.0, module_id=0, track_id=1, extra={}), Hit(hit_id=6, x=np.float64(-0.2923672029594969), y=np.float64(3.2440790466301803), z=133.0, module_id=1, track_id=1, extra={}), Hit(hit_id=7, x=np.float64(-0.4463688561728237), y=np.float64(5.168366262264423), z=166.0, module_id=2, track_id=1, extra={}), Hit(hit_id=8, x=np.float64(-0.6003700052339379), y=np.float64(7.092653446659307), z=199.0, module_id=3, track_id=1, extra={}), Hit(hit_id=9, x=np.float64(-0.7543714343859789), y=np.float64(9.016940574618285), z=232.0, module_id=4, track_id=1, extra={}), Hit(hit_id=10, x=np.float64(-3.1772576986718404), y=np.float64(1.0502428655873706), z=100.0, module_id=0, track_id=2, extra={}), Hit(hit_id=11, x=np.float64(-7.264695758400997), y=np.float64(2.6256338176556993), z=133.0, module_id=1, track_id=2, extra={}), Hit(hit_id=12, x=np.float64(-11.352133801045934), y=np.float64(4.20102508892619), z=166.0, module_id=2, track_id=2, extra={}), Hit(hit_id=13, x=np.float64(-15.439571568126027), y=np.float64(5.776416246738114), z=199.0, module_id=3, track_id=2, extra={}), Hit(hit_id=14, x=np.float64(-19.527008904386708), y=np.float64(7.351806477190838), z=232.0, module_id=4, track_id=2, extra={}), Hit(hit_id=15, x=np.float64(-2.788445307550414), y=np.float64(0.283398882084952), z=100.0, module_id=0, track_id=3, extra={}), Hit(hit_id=16, x=np.float64(-6.372617615607759), y=np.float64(0.866213298577664), z=133.0, module_id=1, track_id=3, extra={}), Hit(hit_id=17, x=np.float64(-9.956790490256445), y=np.float64(1.449027952305753), z=166.0, module_id=2, track_id=3, extra={}), Hit(hit_id=18, x=np.float64(-13.540963371376625), y=np.float64(2.0318425693865674), z=199.0, module_id=3, track_id=3, extra={}), Hit(hit_id=19, x=np.float64(-17.125136206478853), y=np.float64(2.6146570725812612), z=232.0, module_id=4, track_id=3, extra={})], modules=[Module(module_id=0, z=100.0, lx=50.0, ly=50.0, hit_ids=[0, 5, 10, 15], extra={}), Module(module_id=1, z=133.0, lx=50.0, ly=50.0, hit_ids=[1, 6, 11, 16], extra={}), Module(module_id=2, z=166.0, lx=50.0, ly=50.0, hit_ids=[2, 7, 12, 17], extra={}), Module(module_id=3, z=199.0, lx=50.0, ly=50.0, hit_ids=[3, 8, 13, 18], extra={}), Module(module_id=4, z=232.0, lx=50.0, ly=50.0, hit_ids=[4, 9, 14, 19], extra={})], metadata={'generator': 'StateEventGenerator', 'geometry_class': 'PlaneGeometry', 'n_modules': 5, 'z_positions': [100.0, 133.0, 166.0, 199.0, 232.0], 'module_ids': [0, 1, 2, 3, 4], 'phi_min': -0.2, 'phi_max': 0.2, 'theta_min': -0.2, 'theta_max': 0.2, 'events': 1, 'n_particles': [4], 'measurement_error': 0.0, 'collision_noise': 1e-08}),
#   'reco_tracks': [Track(track_id=0, pv_id=0, hit_ids=[0, 1, 2, 3, 4], extra={}),
#    Track(track_id=1, pv_id=0, hit_ids=[5, 6, 7, 8, 9], extra={}),
#    Track(track_id=2, pv_id=0, hit_ids=[10, 11, 12, 13, 14], extra={}),
#    Track(track_id=3, pv_id=0, hit_ids=[15, 16, 17, 18, 19], extra={})],
#   'true_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14),
#    (15, 16),
#    (16, 17),
#    (17, 18),
#    (18, 19)],
#   'reco_segments': [(0, 1),
#    (1, 2),
#    (2, 3),
#    (3, 4),
#    (5, 6),
#    (6, 7),
#    (7, 8),
#    (8, 9),
#    (10, 11),
#    (11, 12),
#    (12, 13),
#    (13, 14),
#    (15, 16),
#    (16, 17),
#    (17, 18),
#    (18, 19)],
#   'matches': [Match(best_truth_id=0, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=0, is_clone=False),
#    Match(best_truth_id=1, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=1, is_clone=False),
#    Match(best_truth_id=2, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=2, is_clone=False),
#    Match(best_truth_id=3, rec_hits=5, truth_hits=5, correct_hits=5, purity=1.0, hit_efficiency=1.0, candidate=True, accepted=True, truth_id=3, is_clone=False)],
#   'metrics': {'efficiency': 1.0,
#    'ghost_rate': 0.0,
#    'clone_fraction': 0.0,
#    'mean_purity': 1.0,
#    'hit_efficiency': 1.0,
#    'n_candidates': 4,
#    'n_accepted': 4,
#    'n_ghosts': 0,
#    'n_clones': 0,
#    'n_primary': 4,
#    'n_reconstructible': 4,
#    'n_matched': 4},
#   'ham': <lhcb_velo_toy.solvers.hamiltonians.fast.SimpleHamiltonianFast at 0x7fccd51fa600>,
#   'x': array([0.90909091, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.90909091, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.90909091, 0.4       , 0.4       , 0.4       , 0.4       ,
#          0.90909091, 1.27272727, 0.4       , 0.4       , 0.4       ,
#          0.4       , 1.27272727, 0.4       , 0.4       , 0.4       ,
#          0.4       , 1.27272727, 0.4       , 0.4       , 0.4       ,
#          0.4       , 1.27272727, 1.27272727, 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.4       , 0.4       ,
#          0.4       , 0.4       , 1.27272727, 0.90909091, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.90909091, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.90909091, 0.4       ,
#          0.4       , 0.4       , 0.4       , 0.90909091])}]

# %%
# ── Per-event: pairwise angles for segment pairs sharing a middle hit ─
# A "true pair" requires all 3 hits (a, mid, c) on the SAME track.

for ed in events_data:
    event_id = ed['event_id']
    event = ed['event']
    hits_dict = {hit.hit_id: hit for hit in event.hits}

    # Build true segment set
    true_seg_set = set()
    for trk in event.tracks:
        hids = trk.hit_ids
        for j in range(len(hids) - 1):
            true_seg_set.add((hids[j], hids[j + 1]))

    # Group hits by module
    hits_by_module = {}
    for h in event.hits:
        hits_by_module.setdefault(h.module_id, []).append(h)
    sorted_mod_ids = sorted(hits_by_module.keys())

    true_angles = []
    false_angles = []

    # For each middle module, pair incoming and outgoing segments
    for mi in range(1, len(sorted_mod_ids) - 1):
        mod_prev = sorted_mod_ids[mi - 1]
        mod_mid  = sorted_mod_ids[mi]
        mod_next = sorted_mod_ids[mi + 1]

        for h_mid in hits_by_module[mod_mid]:
            for h_prev in hits_by_module[mod_prev]:
                v1 = np.array([h_mid.x - h_prev.x, h_mid.y - h_prev.y, h_mid.z - h_prev.z])
                n1 = np.linalg.norm(v1)
                if n1 == 0: continue
                v1 /= n1
                seg_in_true = (h_prev.hit_id, h_mid.hit_id) in true_seg_set

                for h_next in hits_by_module[mod_next]:
                    v2 = np.array([h_next.x - h_mid.x, h_next.y - h_mid.y, h_next.z - h_mid.z])
                    n2 = np.linalg.norm(v2)
                    if n2 == 0: continue
                    v2 /= n2
                    seg_out_true = (h_mid.hit_id, h_next.hit_id) in true_seg_set

                    angle = np.arccos(np.clip(np.dot(v1, v2), -1.0, 1.0))

                    # True pair: both segments true AND all 3 hits on same track
                    if (seg_in_true and seg_out_true and
                            h_prev.track_id is not None and
                            h_prev.track_id == h_mid.track_id == h_next.track_id):
                        true_angles.append(angle)
                    else:
                        false_angles.append(angle)

    fig, ax = plt.subplots(figsize=(10, 6))
    if true_angles:
        ax.hist(true_angles, bins=50, alpha=0.6, color='green',
                label=f'True pairs - same track ({len(true_angles)})', edgecolor='black')
    if false_angles:
        ax.hist(false_angles, bins=50, alpha=0.6, color='red',
                label=f'False pairs ({len(false_angles)})', edgecolor='black')
    ax.axvline(x=EPSILON, color='blue', ls='--', lw=2, label=f'e = {EPSILON:.4f}')
    ax.set_xlabel('Pairwise angle between segments (rad)', fontsize=12)
    ax.set_ylabel('Count', fontsize=12)
    ax.set_title(f'Event {event_id}: Segment-Pair Angles (shared middle hit)\n'
                 f'({len(true_angles)} true, {len(false_angles)} false)', fontsize=14)
    ax.legend()
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
# ── Aggregate pairwise segment angles across ALL events ──────────
# Only segment pairs sharing a middle hit. "True" = all 3 hits same track.

combined_true_angles = []
combined_false_angles = []

for ed in events_data:
    event = ed['event']
    hits_dict = {hit.hit_id: hit for hit in event.hits}

    true_seg_set = set()
    for trk in event.tracks:
        hids = trk.hit_ids
        for j in range(len(hids) - 1):
            true_seg_set.add((hids[j], hids[j + 1]))

    hits_by_module = {}
    for h in event.hits:
        hits_by_module.setdefault(h.module_id, []).append(h)
    sorted_mod_ids = sorted(hits_by_module.keys())

    for mi in range(1, len(sorted_mod_ids) - 1):
        mod_prev = sorted_mod_ids[mi - 1]
        mod_mid  = sorted_mod_ids[mi]
        mod_next = sorted_mod_ids[mi + 1]

        for h_mid in hits_by_module[mod_mid]:
            for h_prev in hits_by_module[mod_prev]:
                v1 = np.array([h_mid.x - h_prev.x, h_mid.y - h_prev.y, h_mid.z - h_prev.z])
                n1 = np.linalg.norm(v1)
                if n1 == 0: continue
                v1 /= n1
                seg_in_true = (h_prev.hit_id, h_mid.hit_id) in true_seg_set

                for h_next in hits_by_module[mod_next]:
                    v2 = np.array([h_next.x - h_mid.x, h_next.y - h_mid.y, h_next.z - h_mid.z])
                    n2 = np.linalg.norm(v2)
                    if n2 == 0: continue
                    v2 /= n2
                    seg_out_true = (h_mid.hit_id, h_next.hit_id) in true_seg_set

                    angle = np.arccos(np.clip(np.dot(v1, v2), -1.0, 1.0))

                    if (seg_in_true and seg_out_true and
                            h_prev.track_id is not None and
                            h_prev.track_id == h_mid.track_id == h_next.track_id):
                        combined_true_angles.append(angle)
                    else:
                        combined_false_angles.append(angle)

combined_true_angles = np.array(combined_true_angles)
combined_false_angles = np.array(combined_false_angles)
print(f"Combined: {len(combined_true_angles):,} true pairs (same track), "
      f"{len(combined_false_angles):,} false pairs from {len(events_data)} events")

# ── Plot ──
bins = np.linspace(0, np.pi/2, 80)

fig, axes = plt.subplots(1, 3, figsize=(20, 5))

axes[0].hist(combined_true_angles, bins=bins, color='forestgreen', alpha=0.8,
             edgecolor='black', lw=0.3, label=f'True ({len(combined_true_angles):,})')
axes[0].axvline(EPSILON, color='blue', ls='--', lw=2, label=f'e = {EPSILON:.4f}')
axes[0].set_title('True Segment Pairs (same track)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Pairwise angle (rad)')
axes[0].set_ylabel('Count')
axes[0].legend(fontsize=10); axes[0].grid(alpha=0.3)

axes[1].hist(combined_false_angles, bins=bins, color='indianred', alpha=0.8,
             edgecolor='black', lw=0.3, label=f'False ({len(combined_false_angles):,})')
axes[1].axvline(EPSILON, color='blue', ls='--', lw=2, label=f'e = {EPSILON:.4f}')
axes[1].set_title('False Segment Pairs', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Pairwise angle (rad)')
axes[1].set_ylabel('Count')
axes[1].legend(fontsize=10); axes[1].grid(alpha=0.3)

axes[2].hist(combined_true_angles, bins=bins, color='forestgreen', alpha=0.6,
             edgecolor='black', lw=0.3, density=True, label=f'True ({len(combined_true_angles):,})')
axes[2].hist(combined_false_angles, bins=bins, color='indianred', alpha=0.5,
             edgecolor='black', lw=0.3, density=True, label=f'False ({len(combined_false_angles):,})')
axes[2].axvline(EPSILON, color='blue', ls='--', lw=2, label=f'e = {EPSILON:.4f}')
axes[2].set_title('True vs False (normalised)', fontsize=14, fontweight='bold')
axes[2].set_xlabel('Pairwise angle (rad)')
axes[2].set_ylabel('Density')
axes[2].legend(fontsize=10); axes[2].grid(alpha=0.3)

plt.suptitle(f'Combined Pairwise Segment Angles (shared middle hit) - {len(events_data)} events',
             fontsize=15, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('baseline_fig4_seg_angles_10events.png', bbox_inches='tight', dpi=120)
plt.show()
# Out:
# Combined: 106 true pairs (same track), 1,742 false pairs from 10 events

# %%
# ── Generate many events x 50 tracks - PAIRWISE segment angles ───
# Angle between segment pairs sharing a middle hit.
# True pair = all 3 hits on the same track.

N_EVENTS = 20          # reduced from 100 for report generation speed
N_TRACKS_STUDY = 50

all_true_angles = []
all_false_angles = []

for ev_i in range(N_EVENTS):
    for attempt in range(20):
        _, evt = generate_event(geo_clean, N_TRACKS_STUDY)
        if min(len(t.hit_ids) for t in evt.tracks) >= 3:
            break

    hits_dict = {h.hit_id: h for h in evt.hits}

    # True segment set for this event
    true_seg_set = set()
    for trk in evt.tracks:
        hids = trk.hit_ids
        for k in range(len(hids) - 1):
            true_seg_set.add((hids[k], hids[k + 1]))

    # Group hits by module
    hits_by_module = {}
    for h in evt.hits:
        hits_by_module.setdefault(h.module_id, []).append(h)
    sorted_mod_ids = sorted(hits_by_module.keys())

    # For each middle module, pair incoming + outgoing segments through each middle hit
    for mi in range(1, len(sorted_mod_ids) - 1):
        mod_prev = sorted_mod_ids[mi - 1]
        mod_mid  = sorted_mod_ids[mi]
        mod_next = sorted_mod_ids[mi + 1]

        for h_mid in hits_by_module[mod_mid]:
            for h_prev in hits_by_module[mod_prev]:
                v1 = np.array([h_mid.x - h_prev.x, h_mid.y - h_prev.y, h_mid.z - h_prev.z])
                n1 = np.linalg.norm(v1)
                if n1 == 0: continue
                v1 /= n1
                seg_in_true = (h_prev.hit_id, h_mid.hit_id) in true_seg_set

                for h_next in hits_by_module[mod_next]:
                    v2 = np.array([h_next.x - h_mid.x, h_next.y - h_mid.y, h_next.z - h_mid.z])
                    n2 = np.linalg.norm(v2)
                    if n2 == 0: continue
                    v2 /= n2
                    seg_out_true = (h_mid.hit_id, h_next.hit_id) in true_seg_set

                    angle = np.arccos(np.clip(np.dot(v1, v2), -1.0, 1.0))

                    # True pair: both segments true + all 3 hits on SAME track
                    if (seg_in_true and seg_out_true and
                            h_prev.track_id is not None and
                            h_prev.track_id == h_mid.track_id == h_next.track_id):
                        all_true_angles.append(angle)
                    else:
                        all_false_angles.append(angle)

    if (ev_i + 1) % 10 == 0:
        print(f"  {ev_i + 1}/{N_EVENTS} events processed")

all_true_angles = np.array(all_true_angles)
all_false_angles = np.array(all_false_angles)
print(f"\nDone - {len(all_true_angles):,} true segment pairs, "
      f"{len(all_false_angles):,} false segment pairs "
      f"from {N_EVENTS} events x {N_TRACKS_STUDY} tracks")
# Out:
#   20/100 events processed
#   40/100 events processed
#   60/100 events processed
#   80/100 events processed
#   100/100 events processed
#
# Done - 14,488 true segment pairs, 36,005,462 false segment pairs from 100 events x 50 tracks

# %%
# ── Pairwise segment angle histograms with epsilon overlay ───────

bins = np.linspace(0, 0.5, 120)

fig, axes = plt.subplots(1, 3, figsize=(20, 5))

axes[0].hist(all_true_angles, bins=bins, color='forestgreen', alpha=0.8,
             edgecolor='black', lw=0.3, label=f'True ({len(all_true_angles):,})')
axes[0].axvline(EPSILON, color='blue', ls='--', lw=2,
                label=f'$\\varepsilon$ = {EPSILON:.4f}')
axes[0].set_title('True Segment Pairs (same track)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Pairwise angle between segments (rad)')
axes[0].set_ylabel('Count')
axes[0].legend(fontsize=10); axes[0].grid(alpha=0.3)

axes[1].hist(all_false_angles, bins=bins, color='indianred', alpha=0.8,
             edgecolor='black', lw=0.3, label=f'False ({len(all_false_angles):,})')
axes[1].axvline(EPSILON, color='blue', ls='--', lw=2,
                label=f'$\\varepsilon$ = {EPSILON:.4f}')
axes[1].set_title('False Segment Pairs', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Pairwise angle between segments (rad)')
axes[1].set_ylabel('Count')
axes[1].legend(fontsize=10); axes[1].grid(alpha=0.3)

axes[2].hist(all_true_angles, bins=bins, color='forestgreen', alpha=0.6,
             edgecolor='black', lw=0.3, density=True,
             label=f'True ({len(all_true_angles):,})')
axes[2].hist(all_false_angles, bins=bins, color='indianred', alpha=0.5,
             edgecolor='black', lw=0.3, density=True,
             label=f'False ({len(all_false_angles):,})')
axes[2].axvline(EPSILON, color='blue', ls='--', lw=2,
                label=f'$\\varepsilon$ = {EPSILON:.4f}')
axes[2].set_title('True vs False (normalised)', fontsize=14, fontweight='bold')
axes[2].set_xlabel('Pairwise angle between segments (rad)')
axes[2].set_ylabel('Density')
axes[2].legend(fontsize=10); axes[2].grid(alpha=0.3)

plt.suptitle(f'Pairwise Segment Angles - {N_EVENTS} events x {N_TRACKS_STUDY} tracks',
             fontsize=15, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('baseline_fig5_seg_angles_100x50.png', bbox_inches='tight', dpi=120)
plt.show()
